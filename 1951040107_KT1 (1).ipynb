# %% [markdown]
# Cau 1

# %%
print ("CHUONG TRINH XAC DINH SO CHAN-LE")
a=float(input("Nhap vao so a: "))
if (a % 2) == 0:
   print('Đây là số chẵn')
else:
   print('Đây là số lẻ')

# %% [markdown]
# Cau 2

# %%
def check_number(n):
  for i in range(2,n):
     if n % i == 0:
       return False
       return True
while True:
   n = int(input("Hãy nhập vào 1 số nguyên tố duy nhất ")) 
   if check_number(n) == False:
     print("Xin hãy nhập lại...")
   else:
     break
# Out:
# Hãy nhập vào 1 số nguyên tố duy nhất 4
# Xin hãy nhập lại...
# Hãy nhập vào 1 số nguyên tố duy nhất 8
# Xin hãy nhập lại...
# Hãy nhập vào 1 số nguyên tố duy nhất 3

# %% [markdown]
# Cau 3

# %%
array=[1,3,5,7,9]
def inverse_array(k):
  print(list(reversed(array)))
inverse_array(array)
# Out:
# [9, 7, 5, 3, 1]

# %% [markdown]
# Cau 4

# %%
import math
def fibonacci(n):
    if (n < 0):
        return -1;
    elif (n == 0 or n == 1):
        return n;
    else:
        return fibonacci(n - 1) + fibonacci(n - 2);
def isPrimeNumber(n):
    if (n < 2):
         return False;
    # check so nguyen to khi n >= 2
    squareRoot = int(math.sqrt(n));
    for i in range(2, squareRoot + 1):
        if (n % i == 0):
            return False;
    return True;
 
n = int(input("Nhập số nguyên dương n = "));
print ("Tất cả các số fibonacci nhỏ hơn", n, "và nguyên tố:");
i = 0;
fin = fibonacci(i);
while(fin < n):
    fin = fibonacci(i);
    if (isPrimeNumber(fin)):
        print(fin)
    i = i + 1;
# Out:
# Nhập số nguyên dương n = 14
# Tất cả các số fibonacci nhỏ hơn 14 và nguyên tố:
# 2
# 3
# 5
# 13
